# %% [markdown]
# # Crypto Analysis Notebook
#
# This notebook analyzes cryptocurrency data: merging historical and yearly datasets, cleaning, exploratory data analysis, hypothesis testing, and machine learning models to predict next-day prices.

# %%
# imports
import csv
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')

# %%
# loading the dataset
df =

# %% [markdown]
# ## Data Sources
#
# - `crypto_historical_365days.csv`: daily historical price, volume, market cap and derived indicators.
# - `crypto_yearly_performance.csv`: yearly start/end prices and total returns per coin.
#
# Load these files into the following cells and verify their contents before continuing.

# %% [markdown]
# ## Actual vs Predicted Next-Day Price
#
# Line chart comparing actual next-day prices to model predictions (Linear Regression and Random Forest). Use this to visually assess model fit, timing of errors, and periods where models diverge.

# %%
# quick plot: actual vs predicted (last 100 points)
import matplotlib.pyplot as plt
nplot = min(100, len(y_test))
if nplot > 0:
    idx = list(range(len(y_test)))[:nplot]
    plt.figure(figsize=(10,5))
    plt.plot(idx, y_test.iloc[:nplot].values, label='Actual')
    plt.plot(idx, pred_lr[:nplot], label='Pred LR')
    plt.plot(idx, pred_rf[:nplot], label='Pred RF')
    plt.title(f'Actual vs Predicted Next-Day Price for {coin_name}')
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print('Not enough test points to plot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # quick plot: actual vs predicted (last 100 points)
#       2 import matplotlib.pyplot as plt
# ----> 3 nplot = min(100, len(y_test))
#       4 if nplot > 0:
#       5     idx = list(range(len(y_test)))[:nplot]
#
# NameError: name 'y_test' is not defined

# %%
#jdsfsja,dlfjasl;dfjfjasd;lfjasd;lfjasd;lfjasd;lfjasd;
